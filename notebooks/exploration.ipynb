# %%
import pandas as pd

df = pd.read_csv(
    "../data/raw/weather_history.csv"
)

df.head()
# Out:
#            datetime  temperature  humidity  pressure  wind_speed  \
# 0  2025-09-16T00:00          9.4        93    1027.3         1.4
# 1  2025-09-16T01:00          9.2        93    1027.2         0.8
# 2  2025-09-16T02:00          9.0        93    1027.2         0.6
# 3  2025-09-16T03:00          8.7        96    1027.0         0.7
# 4  2025-09-16T04:00          7.3       100    1027.4         0.9
#
#    wind_direction  precipitation  cloud_cover       city
# 0             247            0.0            0  innopolis
# 1             297            0.0            0  innopolis
# 2             326            0.0            0  innopolis
# 3             346            0.0            0  innopolis
# 4             281            0.0          100  innopolis

# %%
df.shape
# Out:
# (43920, 9)

# %%
df["city"].unique()
# Out:
# <StringArray>
# ['innopolis', 'kazan', 'cheboksary', 'ulyanovsk', 'yoshkar_ola']
# Length: 5, dtype: str

# %%
df.isna().sum()
# Out:
# datetime          0
# temperature       0
# humidity          0
# pressure          0
# wind_speed        0
# wind_direction    0
# precipitation     0
# cloud_cover       0
# city              0
# dtype: int64

# %%
df["datetime"].head()
# Out:
# 0    2025-09-16T00:00
# 1    2025-09-16T01:00
# 2    2025-09-16T02:00
# 3    2025-09-16T03:00
# 4    2025-09-16T04:00
# Name: datetime, dtype: str

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

df = pd.read_csv(
    "../data/raw/weather_history.csv",
    parse_dates=["datetime"]
)


print(df.head())
# Out:
#              datetime  temperature  humidity  pressure  wind_speed  \
# 0 2025-09-16 00:00:00          9.4        93    1027.3         1.4
# 1 2025-09-16 01:00:00          9.2        93    1027.2         0.8
# 2 2025-09-16 02:00:00          9.0        93    1027.2         0.6
# 3 2025-09-16 03:00:00          8.7        96    1027.0         0.7
# 4 2025-09-16 04:00:00          7.3       100    1027.4         0.9
#
#    wind_direction  precipitation  cloud_cover       city
# 0             247            0.0            0  innopolis
# 1             297            0.0            0  innopolis
# 2             326            0.0            0  innopolis
# 3             346            0.0            0  innopolis
# 4             281            0.0          100  innopolis

# %%
df = pd.read_csv(
    "../data/processed//test.csv"
)

df.head()
# Out:
#               datetime  cheboksary_temperature  innopolis_temperature  \
# 0  2026-07-05 16:00:00                    25.5                   28.0
# 1  2026-07-05 17:00:00                    27.0                   27.8
# 2  2026-07-05 18:00:00                    26.3                   25.7
# 3  2026-07-05 19:00:00                    25.9                   25.6
# 4  2026-07-05 20:00:00                    24.6                   25.3
#
#    kazan_temperature  ulyanovsk_temperature  yoshkar_ola_temperature  \
# 0               30.0                   29.7                     27.0
# 1               27.6                   29.8                     26.1
# 2               26.7                   28.9                     26.4
# 3               27.2                   26.8                     25.7
# 4               26.7                   26.1                     25.0
#
#    cheboksary_humidity  innopolis_humidity  kazan_humidity  \
# 0                 71.0                50.0            42.0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
df["target_temperature_3h"] = (
    df["innopolis_temperature"]
    .shift(-3)
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...
